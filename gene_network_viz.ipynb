# %%
import os

directory_path = "C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/python_plasmid"
os.chdir(directory_path)

import networkx as nx
import matplotlib.pyplot as plt

IncFII_1 = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFII_1/ggCaller_output/final_graph.gml")
nx.draw(IncFII_1, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFII_1')
plt.show()

# %%
IncFII_1_prefiltered = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFII_1/ggCaller_output/pre_filt_graph.gml")
nx.draw(IncFII_1_prefiltered, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFII_1 Pre-filtered')
plt.show()

# %%
IncFIBK = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_K/ggCaller_output/final_graph.gml")
nx.draw(IncFIBK, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_K')
plt.show()

# %%
IncFIBK_prefiltered = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_K/ggCaller_output/pre_filt_graph.gml")
nx.draw(IncFIBK_prefiltered, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_K Pre-filtered')
plt.show()

# %%
IncFIB_pHCM2 = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB(pHCM2)_1/ggCaller_output/final_graph.gml")
nx.draw(IncFIB_pHCM2, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB(pHCM2)')
plt.show()

# %%
IncFIB_pHCM2_core = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pHCM2/ggCaller_core_output/final_graph.gml")
nx.draw(IncFIB_pHCM2_core, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pHCM2 core alignment')
plt.show()

# %%
IncFIB_pHCM2_prefiltered = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pHCM2/ggCaller_output/pre_filt_graph.gml")
nx.draw(IncFIB_pHCM2_prefiltered, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pHCM2 Pre-filtered')
plt.show()

# %%
IncFIB_pHCM2_core_prefiltered = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pHCM2/ggCaller_core_output/pre_filt_graph.gml")
nx.draw(IncFIB_pHCM2_core_prefiltered, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pHCM2 Core alignment Pre-filtered')
plt.show()

# %%
IncFIB_pKPHS1 = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pKPHS1/ggCaller_output/final_graph.gml")
nx.draw(IncFIB_pKPHS1, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pKPHS1')
plt.show()

# %%
IncFIB_pKPHS1_core = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pKPHS1/ggCaller_core_output/final_graph.gml")
nx.draw(IncFIB_pKPHS1_core, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pKPHS1 Core Alignment')
plt.show()

# %%
IncFIB_pKPHS1_prefiltered = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pKPHS1/ggCaller_output/pre_filt_graph.gml")
nx.draw(IncFIB_pKPHS1_prefiltered, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pKPHS1 Pre-filtered')
plt.show()

# %%
IncFIB_pKPHS1_core_prefiltered = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pKPHS1/ggCaller_core_output/pre_filt_graph.gml")
nx.draw(IncFIB_pKPHS1_core_prefiltered, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pKPHS1 Core Alignment Pre-filtered')
plt.show()

# %%
IncFII_pHN7A8 = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFII_pHN7A8/ggCaller_output/final_graph.gml")
nx.draw(IncFII_pHN7A8, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFII_pHN7A8')
plt.show()

# %%
IncFII_pHN7A8_prefiltered = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFII_pHN7A8/ggCaller_output/pre_filt_graph.gml")
nx.draw(IncFII_pHN7A8_prefiltered, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFII_pHN7A8 Pre-filtered')
plt.show()

# %%
#Now try coinfinder outputs:
IncFIB_pKPHS1_coinfinder = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pKPHS1/ggCaller_core_output/Coinfinder_associations/coinfinder_associate_network.gml")
nx.draw(IncFIB_pKPHS1_coinfinder, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pKPHS1 Coinfinder Gene Associations')
plt.show()

# %%
IncFIB_pHCM2_coinfinder = nx.read_gml("C:/Users/dnagy/OneDrive - Nexus365/Documents/DPhil Clin Medicine/DPhil/F-Plasmid Manuscript/plasmid_families/IncFIB_pHCM2/ggCaller_core_output/Coinfinder_associations/coinfinder_associate_network.gml")
nx.draw(IncFIB_pHCM2_coinfinder, with_labels=True, node_size=10, node_color='skyblue', font_size=4)
plt.title('IncFIB_pHCM2 Coinfinder Gene Associations')
plt.show()
